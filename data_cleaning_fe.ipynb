# %%
import sqlite3
import pandas as pd
import numpy as np
from pathlib import Path


# Configuration
DB = "resqfood.db"
OUT_CSV = "resqfood_processed.csv"

# Load Data
print("Loading data from database...")

try:
    with sqlite3.connect(DB) as conn:
        df = pd.read_sql(
            "SELECT * FROM listings",
            conn,
            parse_dates=["time_posted"]
        )
except Exception as e:
    raise RuntimeError(f"Database load failed: {e}")

print(f"Loaded {len(df)} rows")


# Remove duplicates
if "listing_id" in df.columns:
    df = df.drop_duplicates(subset=["listing_id"]).copy()

# Fill numeric missing values safely
numeric_fill_cols = ["distance_km", "ambient_temp_c", "quantity"]

for col in numeric_fill_cols:
    if col in df.columns:
        df[col] = df[col].fillna(df[col].median())

# Convert categorical columns
categorical_cols = [
    "donor_type",
    "food_type",
    "unit",
    "city",
    "packaging",
    "donor_reliability"
]

for col in categorical_cols:
    if col in df.columns:
        df[col] = df[col].astype("category")

# Feature Engineering
print("Creating new features...")

# Hour feature
if "time_posted" in df.columns:
    df["hour_posted"] = df["time_posted"].dt.hour

    df["is_peak_hour"] = np.where(
        (df["hour_posted"] >= 8) & (df["hour_posted"] <= 20),
        1,
        0
    )
else:
    df["is_peak_hour"] = 0

# Quantity conversion to kg
unit_to_kg = {
    "kg": 1.0,
    "plates": 0.5,
    "boxes": 2.0,
    "packs": 1.0
}

if "unit" in df.columns and "quantity" in df.columns:
    df["quantity_kg"] = df["quantity"] * df["unit"].map(unit_to_kg).fillna(1.0)
else:
    df["quantity_kg"] = df.get("quantity", 1)

# Donor reliability score
rel_map = {
    "Low": 0.5,
    "Medium": 0.8,
    "High": 1.0
}

if "donor_reliability" in df.columns:
    df["donor_reliability_score"] = df["donor_reliability"].map(rel_map).fillna(0.7)
else:
    df["donor_reliability_score"] = 0.7


# Time-based features
if "time_since_cooked_mins" in df.columns:
    df["time_since_cooked_hours"] = df["time_since_cooked_mins"] / 60
else:
    df["time_since_cooked_hours"] = 1

# Interaction features
df["qty_div_distance"] = df["quantity_kg"] / (df["distance_km"] + 0.5)

if "freshness_score" in df.columns:
    df["freshness_by_pack"] = (
        df["freshness_score"] * df["donor_reliability_score"]
    )
else:
    df["freshness_by_pack"] = df["donor_reliability_score"]

# One-hot encoding

print("Encoding categorical variables...")

encode_cols = [
    "donor_type",
    "food_type",
    "city",
    "packaging"
]

existing_encode_cols = [c for c in encode_cols if c in df.columns]

df_for_model = pd.get_dummies(
    df,
    columns=existing_encode_cols,
    drop_first=True
)

# Feature Selection
print("Selecting model features...")

base_features = [
    "quantity_kg",
    "distance_km",
    "ambient_temp_c",
    "time_since_cooked_hours",
    "donor_reliability_score",
    "is_peak_hour",
    "qty_div_distance"
]

encoded_features = [
    c for c in df_for_model.columns
    if c.startswith(
        ("donor_type_", "food_type_", "city_", "packaging_")
    )
]

features = base_features + encoded_features

target_class = "picked_up"
target_reg = "freshness_score"

X = df_for_model[features]

y_class = df_for_model[target_class] if target_class in df_for_model else None
y_reg = df_for_model[target_reg] if target_reg in df_for_model else None

# Final Dataset
processed = pd.concat(
    [
        X,
        y_class if y_class is not None else pd.DataFrame(),
        y_reg if y_reg is not None else pd.DataFrame(),
        df[["listing_id", "time_posted"]].reset_index(drop=True)
        if "listing_id" in df.columns else pd.DataFrame()
    ],
    axis=1
)

# Save CSV
processed.to_csv(OUT_CSV, index=False)
print(f"Processed CSV saved → {OUT_CSV}")

# Save to SQLite
with sqlite3.connect(DB) as conn:
    processed.to_sql(
        "listings_clean",
        conn,
        if_exists="replace",
        index=False
    )

print("Clean table written to SQLite → listings_clean")
print("Pipeline completed successfully.")

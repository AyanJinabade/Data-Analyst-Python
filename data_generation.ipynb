# %%
import numpy as np
import pandas as pd
import datetime
import random


# Random Seed (Reproducibility)


RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

# Number of listings
N = 5000



# Static Data


donor_types = ['Restaurant', 'Bakery', 'Caterer', 'HomeCook', 'Society', 'Event']

food_types = ['Cooked Meal', 'Fruits', 'Salads', 'Baked Goods', 'Desserts', 'Beverage']

units = ['kg', 'boxes', 'plates', 'packs']

cities = ['Bengaluru', 'Mumbai', 'Delhi', 'Hyderabad', 'Chennai', 'Pune']

packaging_types = ['Airtight', 'Open Tray', 'Covered Tray', 'Sealed Box', 'Cloth Wrap']

donor_reliability_levels = ['Low', 'Medium', 'High']


# Factors used for scoring

packaging_factor = {
    'Airtight': 1.0,
    'Sealed Box': 0.95,
    'Covered Tray': 0.85,
    'Open Tray': 0.6,
    'Cloth Wrap': 0.5
}

food_type_factor = {
    'Cooked Meal': 0.9,
    'Fruits': 0.95,
    'Salads': 0.7,
    'Baked Goods': 0.85,
    'Desserts': 0.9,
    'Beverage': 0.95
}

donor_reliability_factor = {
    'High': 1.0,
    'Medium': 0.9,
    'Low': 0.75
}

ngo_density = {
    'Bengaluru': 0.9,
    'Mumbai': 0.95,
    'Delhi': 0.9,
    'Hyderabad': 0.7,
    'Chennai': 0.6,
    'Pune': 0.65
}


# Base time
base_time = datetime.datetime(2025, 9, 1, 7, 0, 0)

rows = []

for i in range(N):

    listing_id = f"L{i+1:05d}"
    donor_id = f"D{random.randint(1,800):04d}"

    donor_type = np.random.choice(donor_types, p=[0.35,0.1,0.1,0.2,0.15,0.1])

    food_type = np.random.choice(food_types, p=[0.5,0.1,0.08,0.15,0.1,0.07])

    quantity = max(0.5, round(np.random.exponential(scale=5.0),1))

    unit = random.choice(units)

    city = random.choice(cities)

    packaging = np.random.choice(packaging_types, p=[0.3,0.2,0.25,0.18,0.07])

    # realistic posting time
    time_posted = base_time + datetime.timedelta(
        minutes=int(np.random.exponential(scale=600))
    )

    # cooking time
    cooking_offset = int(np.random.normal(loc=90, scale=60))

    if cooking_offset < 5:
        cooking_offset = random.randint(5,40)

    time_since_cooked = cooking_offset

    donor_reliability = np.random.choice(
        donor_reliability_levels,
        p=[0.25,0.45,0.3]
    )

    distance_km = float(np.clip(np.random.normal(loc=5, scale=4),0.2,40))

    # ambient temperature
    temp_c = float(np.clip(
        np.random.normal(loc=30 - 0.3*(time_since_cooked/60), scale=3),
        10,
        45
    ))

    
    # Freshness Score
    

    base_freshness = max(0, 1 - (time_since_cooked / 360))

    distance_factor = max(0.2, 1 - (distance_km / 50))

    freshness_score = np.clip(
        base_freshness
        * packaging_factor[packaging]
        * food_type_factor[food_type]
        * donor_reliability_factor[donor_reliability]
        * distance_factor
        + np.random.normal(0,0.03),
        0,
        1
    )


    
    # Pickup Probability
    

    qty_factor = min(1, quantity/20)

    hour = time_posted.hour

    hour_factor = 0.9 if 8 <= hour <= 20 else 0.6

    pickup_prob = np.clip(
        0.15
        + 0.6*freshness_score
        + 0.1*qty_factor
        + 0.05*donor_reliability_factor[donor_reliability]
        + 0.05*ngo_density[city]
        + 0.05*hour_factor
        + np.random.normal(0,0.05),
        0,
        1
    )

    picked_up = int(np.random.rand() < pickup_prob)


    rows.append({

        "listing_id": listing_id,
        "donor_id": donor_id,
        "donor_type": donor_type,
        "food_type": food_type,
        "quantity": quantity,
        "unit": unit,
        "city": city,
        "packaging": packaging,
        "time_posted": time_posted.strftime("%Y-%m-%d %H:%M:%S"),
        "time_since_cooked_mins": time_since_cooked,
        "donor_reliability": donor_reliability,
        "distance_km": round(distance_km,2),
        "ambient_temp_c": round(temp_c,1),
        "freshness_score": round(float(freshness_score),3),
        "pickup_prob": round(float(pickup_prob),3),
        "picked_up": picked_up

    })



# Create DataFrame


df = pd.DataFrame(rows)

df.to_csv("resqfood_listings.csv", index=False)

print("Dataset generated successfully")
print("Rows:", len(df))

print("\nSample Data:")
print(df.head())
# Out:
# Generated resqfood_listings.csv with 5000 rows
